# %%
import os
import locale
import modal
from agents.preprocessor import Preprocessor
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# False

# %%
# To check that your computer can output special characters, make sure this outputs UTF-8 

print(locale.getpreferredencoding())  # Should print 'UTF-8'

# %%
os.environ["PYTHONIOENCODING"] = "utf-8"

# %%
# !uv run modal deploy -m pricer_service
# Out:
# - Creating objects...
# \ Creating objects...
# / Creating objects...
# \ Creating objects...
# └── -
# / Creating objects...
# └── \
# \ Creating objects...
# └── / Creating mount
#     d:\MLProjects\GenAI\projects\Week8Projects\agentic_workflow\pricer_service.
#     py: Finalizing index of 1 files
# / Creating objects...
# └── \ Creating mount
#     d:\MLProjects\GenAI\projects\Week8Projects\agentic_workflow\pricer_service.
#     py: Finalizing index of 1 files
# \ Creating objects...
# ├── 🔨 Created mount
# │   d:\MLProjects\GenAI\projects\Week8Projects\agentic_workflow\pricer_service.
# │   py
# └── - Creating function price...
# / Creating objects...
# ├── 🔨 Created mount
# │   d:\MLProjects\GenAI\projects\Week8Projects\agentic_workflow\pricer_service.
# │   py
# └── | Creating function price...
# | Creating objects...
# ├── 🔨 Created mount
# │   d:\MLProjects\GenAI\projects\Week8Projects\agentic_workflow\pricer_service.
# │   py
# └── / Creating function price...
# | Creating objects...
# ├── 🔨 Created mount
# │   d:\MLProjects\GenAI\projects\Week8Projects\agentic_workflow\pricer_service.
# │   py
# └── 🔨 Created function price.
#
# ✓ Created objects.
# ├── 🔨 Created mount
# │   d:\MLProjects\GenAI\projects\Week8Projects\agentic_workflow\pricer_service.
# │   py
# └── 🔨 Created function price.
# ✓ App deployed in 4.226s! 🎉
#
# View Deployment:
# https://modal.com/apps/techayush009/main/deployed/pricer-service

# %%
preprocessor = Preprocessor()
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %%
pricer.remote(text)
